# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from scipy.ndimage.filters import gaussian_filter1d

#model
from sklearn.cluster import AgglomerativeClustering

#visualization
from scipy.cluster.hierarchy import dendrogram
# packages for cluster determination 
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %% [markdown]
# # 1. Clustering avg. Baseline consumption

# %%
# load consumption data
consumption = pd.read_pickle('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Consumption_Matrices/{}_accounts_actual_usage'.format('MD'))

# compute avg. consumption for baseline 
time_base = pd.date_range(start='1/1/2002',  end='11/1/2007', freq='2MS')
consumption_base = consumption[time_base]

consumption_avg = pd.DataFrame(index=consumption.index)
consumption_avg['avg_consumption'] = consumption_base.mean(axis=1)

# %%
model = AgglomerativeClustering( n_clusters=5, linkage='ward')
model = model.fit(consumption_avg)

clusters = pd.DataFrame(index=consumption.index)
clusters['avg_consump'] = model.labels_
clusters['pattern']=  np.nan

# %%
consumption_avg['cluster'] = clusters['avg_consump']

# %%
consumption_avg.groupby('cluster').mean()
# Out:
#          avg_consumption
# cluster
# 0             831.034973
# 1            2854.992810
# 2           11214.623728
# 3            5266.425518
# 4            6757.114344

# %% [markdown]
# # Cluster on Pattern

# %%
# load pattern
pattern = pd.read_pickle('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Residuals/pattern_MD')

# %%
# silhouette score
cluster_groups = clusters.groupby('avg_consump')

for name, group in cluster_groups:
  pattern_group = pattern.loc[group.index].pattern.apply(pd.Series)
  range_n_clusters = range(2,10)

  fig, ax = plt.subplots(1, figsize=(10,7))

  silhouettes = []

  for n_clusters in range_n_clusters:
      # Initialize the clusterer with n_clusters value and a random generator
      # seed of 17 for reproducibility.
      clusterer = AgglomerativeClustering(n_clusters=n_clusters, linkage='complete')
      cluster_labels = clusterer.fit_predict(pattern_group)
      # The silhouette_score gives the average value for all the samples.
      # This gives a perspective into the density and separation of the formed
      # clusters
      silhouette_avg = silhouette_score(pattern_group, cluster_labels)
      silhouettes.append(silhouette_avg)
      
  ax.plot(range_n_clusters, silhouettes, 'o-')
  ax.set_ylabel('Average silhouette coefficient')
  ax.set_xlabel('K')
  ax.grid()
  fig.suptitle('Silhouette coefficient for group {}'.format(name))
  plt.show()

# %%
# dendrogramm
cluster_groups = clusters.groupby('avg_consump')

for name, group in cluster_groups:
  pattern_group = pattern.loc[group.index].pattern.apply(pd.Series)

  fig, ax = plt.subplots(1, figsize=(10,7))
  model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage='complete')
  model = model.fit(pattern_group)
  plot_dendrogram(model, truncate_mode='level', p=3 )
  ax.set_ylabel('similarity')
  fig.suptitle('Dendrogram for group {}'.format(name))
  plt.show()

# %%
xtimeline = pd.date_range(start='1/1/2008',  end='7/1/2020', freq='2MS')

# %%
len(time_base)
# Out:
# 76

# %%
cluster_groups = clusters.groupby('avg_consump')
n_clusters = [3, 4, 1, 2, 1]
for i, (name, group) in enumerate(cluster_groups):
  pattern_group = pattern.loc[group.index].pattern.apply(pd.Series)
  model = AgglomerativeClustering( n_clusters=n_clusters[i], linkage='complete')
  labels = model.fit_predict(pattern_group)
  clusters.loc[group.index, 'pattern'] = labels.astype(int)

# %%
clusters#.to_pickle('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Clustering/MD_clusters.pdf')
# Out:
#               avg_consump  pattern
# W_LocationID
# MW10063                 0      2.0
# MW10507                 1      1.0
# MW10952                 0      2.0
# MW11291                 3      1.0
# MW11403                 1      3.0
# ...                   ...      ...
# MW9571                  0      2.0
# MW9572                  0      2.0
# MW9574                  0      2.0
# MW9576                  0      2.0
# MW9578                  0      2.0
#
# [103 rows x 2 columns]

# %% [markdown]
# ## Plots

# %%
pattern_group = clusters.groupby(by=['avg_consump', 'pattern'])

# %%
import enum
timeline = pd.date_range(start='1/1/2008',  end='7/1/2020', freq='2MS')
consump_group = ['low', 'medium', 'extreme','high',  'super']

for i, (name, group) in enumerate(pattern_group):
  toPlotpattern = pattern.loc[group.index].pattern.apply(pd.Series)
  fig, ax = plt.subplots(1, figsize=(10,7))
  # stressors
  ax.fill_between([timeline[0],timeline[12]],-1.5,1.5, color ='red', alpha = 0.2)
  ax.fill_between([timeline[6],timeline[15]],-1.5,1.5, color ='orange', alpha = 0.2)
  ax.fill_between([timeline[36],timeline[54]],-1.5,1.5, color ='red', alpha = 0.2)
  ax.fill_between([timeline[72], timeline[-1]],-1.5,1.5, color ='green', alpha = 0.2)
  #pattern from clusters
  toPlotMean = toPlotpattern.mean(axis=0)
  ax.plot(timeline,toPlotMean)
  ax.fill_between(timeline,toPlotMean-np.std(toPlotpattern, axis=0), toPlotMean+np.std(toPlotpattern, axis=0), color ='cornflowerblue', alpha = 0.3)

  ax.hlines(y=0,xmin=timeline[0], xmax= timeline[-1],  color='k')
  plt.suptitle('Consumption Group {} – Pattern Group {} – Count {}'.format(consump_group[name[0]], name[1], len(toPlotpattern)))
  plt.grid(True)

  #plt.savefig('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Clustering/MD/{}_pattern{}.pdf'.format(consump_group[name[0]], name[1]))
  #plt.close(fig)

# %%
timeline[72]
# Out:
# Timestamp('2020-01-01 00:00:00', freq='2MS')

# %%
timeline = pd.date_range(start='1/1/2008',  end='7/1/2020', freq='2MS')

for name, group in pattern_group:
  toPlotpattern = pattern.loc[group.index].pattern.apply(pd.Series)
  fig, ax = plt.subplots(1, figsize=(10,7))
  toPlotMode = toPlotpattern.mode(axis=0).to_numpy().T
  ax.plot(timeline,toPlotMode)

# %%
timeline = pd.date_range(start='1/1/2008',  end='7/1/2020', freq='2MS')
timeline_drop = pd.date_range(start='1/1/2008',  end='11/1/2018', freq='2MS')
timeline_new = pd.date_range(start='1/1/2019',  end='7/1/2020', freq='2MS')
consump_group = ['low', 'medium', 'extreme','high',  'super']

for i, (name, group) in enumerate(pattern_group):
  toPlotpattern = pattern.loc[group.index].pattern.apply(pd.Series)
  toPlotpattern.columns = timeline
  toPlotpattern.drop(columns=timeline_drop, inplace=True)
  fig, ax = plt.subplots(1, figsize=(10,7))
  # stressors
  #ax.fill_between([timeline[0],timeline[12]],-1.5,1.5, color ='red', alpha = 0.2)
  #ax.fill_between([timeline[6],timeline[15]],-1.5,1.5, color ='orange', alpha = 0.2)
  #ax.fill_between([timeline[36],timeline[54]],-1.5,1.5, color ='red', alpha = 0.2)
  ax.fill_between([timeline_new[-3], timeline_new[-1]],-1.5,1, color ='green', alpha = 0.2)
  #pattern from clusters
  toPlotMean = toPlotpattern.mean(axis=0)
  ax.plot(timeline_new,toPlotMean)
  #ax.fill_between(timeline_new,toPlotMean-np.std(toPlotpattern, axis=0), toPlotMean+np.std(toPlotpattern, axis=0), color ='cornflowerblue', alpha = 0.3)

  #ax.hlines(y=0,xmin=timeline[0], xmax= timeline[-1],  color='k')
  plt.suptitle('Consumption Group {} – Pattern Group {} – Count {}'.format(consump_group[name[0]], name[1], len(toPlotpattern)))
  plt.grid(True)

  #if consump_group[name[0]] != 'super' :


  #plt.savefig('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Clustering/SD/{}_pattern{}.pdf'.format(consump_group[name[0]], name[1]))
  #plt.close(fig)

# %% [markdown]
# ### Barplot+ smooth

# %%
import matplotlib.colors as colors
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

# adapt colormap
cmap = plt.get_cmap('Blues_r')
new_cmap = truncate_colormap(cmap, 0.1, 0.7)

# %%
timeline = pd.date_range(start='1/1/2008',  end='7/1/2020', freq='2MS')
consump_group = ['low', 'medium', 'extreme','high',  'super']

for i, (name, group) in enumerate(pattern_group):
  toPlotpattern = pattern.loc[group.index].pattern.apply(pd.Series)
  toPlotpattern.columns = timeline
  barplot_df = pd.DataFrame(index = timeline, columns= [-1, 0, 1])
  for date in timeline:
    count = pd.value_counts(toPlotpattern[date])
    barplot_df.loc[date] =  count

  # sort groups
  categories = [1, 0, -1]
  barplot_df.columns = pd.CategoricalIndex(barplot_df.columns.values, 
                                 ordered=True, 
                                 categories=categories)
  # Sort the columns (axis=1) by the new categorical ordering
  barplot_df = barplot_df.sort_index(axis=1)
  
  #barplot
  ax1 = barplot_df.plot.bar(stacked=True, figsize=(10,6),color=['tab:red', 'tab:green', 'tab:blue'], width=1, rot=0, legend=False)
  
  #pattern from clusters smoothend
  toPlotMean = toPlotpattern.mean(axis=0)
  MeanSmoothed = pd.DataFrame(index = timeline, columns=['mean'], data =gaussian_filter1d(toPlotMean, sigma=2)) 
  ax2 = ax1.twinx()
  ax2.spines['right'].set_position(('axes', 1.0))
  ax2.set_ylim(-1,1)
  MeanSmoothed.plot(linestyle='-', linewidth = 2, color='k', use_index=False, ax=ax2)
  #ax2.tick_params(axis='y', labelcolor='tab:red')
  
  # merge legends
  lines, labels = ax1.get_legend_handles_labels()
  lines2, labels2 = ax2.get_legend_handles_labels()
  ax2.legend(lines + lines2, ['increase', 'no change', 'decrease'] + labels2)

  n=6
  ticks = ax1.xaxis.get_ticklocs()
  ax1.xaxis.set_ticks(ticks[::n])
  ax1.xaxis.set_ticklabels(barplot_df.index.year[::n])

  ax1.set_ylabel(' Count')
  ax2.set_ylabel(' Mean')

  plt.title('Consumption Group {} – Pattern Group {} – Count {}'.format(consump_group[name[0]], name[1], len(toPlotpattern)))
  plt.savefig('/content/drive/MyDrive/Stanford-TUBerlin/CodePaper/Clustering/MD/barplot/bar_{}_pattern{}.pdf'.format(consump_group[name[0]], name[1]))
  plt.close()
